# %%
# %pip install transformers datasets accelerate torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in c:\users\tl1\anaconda3\lib\site-packages (4.56.2)
# Collecting datasets
#   Downloading datasets-4.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: accelerate in c:\users\tl1\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: torch in c:\users\tl1\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: filelock in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (0.35.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tl1\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tl1\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tl1\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (0.28.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\tl1\anaconda3\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: anyio in c:\users\tl1\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in c:\users\tl1\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\tl1\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\tl1\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\tl1\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: psutil in c:\users\tl1\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tl1\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\tl1\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\tl1\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\tl1\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tl1\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tl1\anaconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tl1\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\tl1\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tl1\anaconda3\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tl1\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tl1\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tl1\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tl1\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tl1\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-4.2.0-py3-none-any.whl (506 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl (26.1 MB)
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    --------------- ------------------------ 10.0/26.1 MB 47.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.9/26.1 MB 45.9 MB/s eta 0:00:01
#    ---------------------------------------- 26.1/26.1 MB 44.8 MB/s eta 0:00:00
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, pyarrow, multiprocess, datasets
#
#   Attempting uninstall: pyarrow
#
#     Found existing installation: pyarrow 19.0.0
#
#     Uninstalling pyarrow-19.0.0:
#
#       Successfully uninstalled pyarrow-19.0.0
#
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    ---------- ----------------------------- 1/4 [pyarrow]
#    -------------------- ------------------- 2/4 [multiprocess]
#    -------------------- ------------------- 2/4 [multiprocess]
#    ------------------------------ --------- 3/4 [datasets]
#    ------------------------------ --------- 3/4 [datasets]
#    ------------------------------ --------- 3/4 [datasets]
#    ------------------------------ --------- 3/4 [datasets]
#    ---------------------------------------- 4/4 [datasets]
#
# Successfully installed datasets-4.2.0 multiprocess-0.70.16 pyarrow-21.0.0 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install transformers datasets accelerate torch pandas
from transformers import MT5ForConditionalGeneration, MT5Tokenizer
from transformers import Trainer, TrainingArguments
from torch.nn import functional as F
import torch
from datasets import load_dataset

# --------------------------
# 1️⃣ Configuration
# --------------------------
csv_path = "healthcare_dataset.csv"   # your dataset filename
model_name = "google/mt5-base"
max_input_len = 256
max_target_len = 128
alpha = 0.6          # CE vs KL loss balance
temperature = 3.0     # distillation temperature
num_epochs = 3
batch_size = 4        # reduced by default to be safer on memory

# --------------------------
# 2️⃣ Load tokenizer and models
# --------------------------
tokenizer = MT5Tokenizer.from_pretrained(model_name)

teacher = MT5ForConditionalGeneration.from_pretrained(model_name)
student = MT5ForConditionalGeneration.from_pretrained(model_name)

# freeze teacher parameters and set eval mode
for param in teacher.parameters():
    param.requires_grad = False
teacher.eval()

device = "cuda" if torch.cuda.is_available() else "cpu"
teacher.to(device)
student.to(device)

# --------------------------
# 3️⃣ Load and preprocess dataset
# --------------------------
# Expected columns in CSV: instruction, input, output
dataset = load_dataset("csv", data_files={"full": csv_path})["full"]

# Split 90/10 into train and validation
dataset = dataset.train_test_split(test_size=0.1, seed=42)

def combine_columns(batch):
    # This version expects batched examples
    src_texts = []
    tgt_texts = []
    for instr, inp, out in zip(batch["instruction"], batch["input"], batch["output"]):
        if inp and str(inp).strip() != "":
            src_texts.append(f"{instr} : {inp}")
        else:
            src_texts.append(instr)
        tgt_texts.append(out)

    model_inputs = tokenizer(
        src_texts,
        max_length=max_input_len,
        truncation=True,
        padding="max_length",
    )
    labels = tokenizer(
        tgt_texts,
        max_length=max_target_len,
        truncation=True,
        padding="max_length",
    )["input_ids"]

    # Replace pad token id's in the labels by -100 so they are ignored by the loss
    labels = [
        [(token if token != tokenizer.pad_token_id else -100) for token in label_seq]
        for label_seq in labels
    ]
    model_inputs["labels"] = labels
    return model_inputs

# Use batched=True for speed and safety; remove original text columns
tokenized_datasets = dataset.map(
    combine_columns,
    batched=True,
    remove_columns=dataset["train"].column_names,
)

# Convert to torch tensors (Trainer will do this automatically if not)
# --------------------------
# 4️⃣ Custom Trainer for Self-Distillation
# --------------------------
class SelfDistillationTrainer(Trainer):
    def __init__(self, teacher_model, temperature, alpha, **kwargs):
        super().__init__(**kwargs)
        self.teacher = teacher_model
        self.temperature = temperature
        self.alpha = alpha

    def compute_loss(self, model, inputs, return_outputs=False):
        # inputs already moved to device by Trainer
        labels = inputs.pop("labels")

        # Teacher forward pass (no grad)
        with torch.no_grad():
            # ensure teacher uses float32 for stability when training uses fp16
            # convert any half tensors to float for teacher ops
            teacher_inputs = {k: v.to(self.teacher.device) for k, v in inputs.items()}
            teacher_outputs = self.teacher(**teacher_inputs)
            teacher_logits = teacher_outputs.logits / self.temperature  # (B, S, V)

        # Student forward pass (gives CE loss)
        outputs = model(**inputs, labels=labels)
        student_logits = outputs.logits / self.temperature

        # Cross-Entropy Loss (hard labels) -- outputs.loss already computed by model
        loss_ce = outputs.loss

        # We want KL over vocabulary dimension; ensure both are float32 for stability
        t_logits = teacher_logits.float()
        s_logits = student_logits.float()

        # KL Divergence Loss (soft labels)
        # compute log-probs and probs along the vocab dim
        s_log_probs = F.log_softmax(s_logits, dim=-1)
        t_probs = F.softmax(t_logits, dim=-1)

        kl_loss = F.kl_div(
            s_log_probs,
            t_probs,
            reduction="batchmean"
        ) * (self.temperature ** 2)

        # Combined loss
        loss = self.alpha * loss_ce + (1.0 - self.alpha) * kl_loss

        return (loss, outputs) if return_outputs else loss

# --------------------------
# 5️⃣ Training Arguments
# --------------------------
training_args = TrainingArguments(
    output_dir="./mt5_sdft_healthcare",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_epochs,
    weight_decay=0.01,
    save_total_limit=2,
    predict_with_generate=True,
    logging_steps=200,
    fp16=False,  # start with False; enable only after confirming correctness
    report_to="none",
    dataloader_pin_memory=True,
)

# --------------------------
# 6️⃣ Initialize Trainer
# --------------------------
trainer = SelfDistillationTrainer(
    teacher_model=teacher,
    model=student,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    tokenizer=tokenizer,
    temperature=temperature,
    alpha=alpha
)

# --------------------------
# 7️⃣ Train and Save
# --------------------------
trainer.train()
trainer.save_model("./mt5_self_distilled_healthcare_student")
tokenizer.save_pretrained("./mt5_self_distilled_healthcare_student")

print("✅ Training complete! Fine-tuned model saved to './mt5_self_distilled_healthcare_student'")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # pip install transformers datasets accelerate torch pandas
#       2 from transformers import MT5ForConditionalGeneration, MT5Tokenizer
# ----> 3 from transformers import Trainer, TrainingArguments
#       4 from torch.nn import functional as F
#       5 import torch
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\TL1\anaconda3\envs\aiml_labexam\lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\TL1\anaconda3\envs\aiml_labexam\lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\TL1\anaconda3\envs\aiml_labexam\lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\TL1\anaconda3\envs\aiml_labexam\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\TL1\anaconda3\envs\aiml_labexam\lib\site-packages\transformers\trainer.py:311
#     301 SCHEDULER_NAME = "scheduler.pt"
#     302 FSDP_MODEL_NAME = "pytorch_model_fsdp"
#     305 @requires(
#     306     backends=(
#     307         "torch",
#     308         "accelerate",
#     309     )
#     310 )
# --> 311 class Trainer:
#     312     """
#     313     Trainer is a simple but feature-complete training and eval loop for PyTorch, optimized for 🤗 Transformers.
#     314
#    (...)
#     403
#     404     """
#     406     # Those are used as methods of the Trainer in examples.
#
# File c:\Users\TL1\anaconda3\envs\aiml_labexam\lib\site-packages\transformers\trainer.py:5593, in Trainer()
#    5584         if (
#    5585             getattr(self.model, "quantization_method", None) == QuantizationMethod.BITS_AND_BYTES
#    5586             and self.model.hf_quantizer.quantization_config.bnb_4bit_quant_storage.is_floating_point
#    5587             and version.parse(accelerate_version) > version.parse("0.27.0")
#    5588         ):
#    5589             self.accelerator.state.fsdp_plugin.set_mixed_precision(
#    5590                 self.model.hf_quantizer.quantization_config.bnb_4bit_quant_storage, override=True
#    5591             )
# -> 5593 def _get_num_items_in_batch(self, batch_samples: list, device: torch.device) -> int | None:
#    5594     """
#    5595     Counts the number of items in the batches to properly scale the loss.
#    5596     Args:
#    (...)
#    5600         None if the number of items in the batch doesn't need to be computed else the number of items in the batch
#    5601     """
#    5602     num_items_in_batch = None
#
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'

# %%
# %pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: datasets in c:\users\tl1\anaconda3\lib\site-packages (4.2.0)
# Requirement already satisfied: filelock in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (2.1.3)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in c:\users\tl1\anaconda3\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (0.35.0)
# Requirement already satisfied: packaging in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tl1\anaconda3\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\tl1\anaconda3\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: anyio in c:\users\tl1\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in c:\users\tl1\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\tl1\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\tl1\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\tl1\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tl1\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tl1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tl1\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tl1\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: colorama in c:\users\tl1\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tl1\anaconda3\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tl1\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tl1\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tl1\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tl1\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U transformers datasets accelerate torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (4.57.0)
# Collecting datasets
#   Downloading datasets-4.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: accelerate in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (1.10.1)
# Requirement already satisfied: torch in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (2.8.0+cu129)
# Requirement already satisfied: filelock in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-21.0.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from datasets) (2.3.3)
# Collecting httpx<1.0.0 (from datasets)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp39-cp39-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py39-none-any.whl.metadata (7.2 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.13.0-cp39-cp39-win_amd64.whl.metadata (8.4 kB)
# Collecting anyio (from httpx<1.0.0->datasets)
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: certifi in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Collecting httpcore==1.* (from httpx<1.0.0->datasets)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from httpx<1.0.0->datasets) (3.10)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0->datasets)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: psutil in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from torch) (3.1.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp39-cp39-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading multidict-6.7.0-cp39-cp39-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading propcache-0.4.1-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading yarl-1.22.0-cp39-cp39-win_amd64.whl.metadata (77 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.2.0)
# Collecting sniffio>=1.1 (from anyio->httpx<1.0.0->datasets)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-4.2.0-py3-none-any.whl (506 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading multiprocess-0.70.16-py39-none-any.whl (133 kB)
# Downloading aiohttp-3.13.0-cp39-cp39-win_amd64.whl (453 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading multidict-6.7.0-cp39-cp39-win_amd64.whl (46 kB)
# Downloading yarl-1.22.0-cp39-cp39-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp39-cp39-win_amd64.whl (44 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading propcache-0.4.1-cp39-cp39-win_amd64.whl (41 kB)
# Downloading pyarrow-21.0.0-cp39-cp39-win_amd64.whl (26.2 MB)
#    ---------------------------------------- 0.0/26.2 MB ? eta -:--:--
#    ------- -------------------------------- 5.0/26.2 MB 23.2 MB/s eta 0:00:01
#    ------------------ --------------------- 12.1/26.2 MB 30.2 MB/s eta 0:00:01
#    -------------------------- ------------- 17.3/26.2 MB 27.3 MB/s eta 0:00:01
#    -------------------------------- ------- 21.2/26.2 MB 25.3 MB/s eta 0:00:01
#    ---------------------------------------  25.7/26.2 MB 24.3 MB/s eta 0:00:01
#    ---------------------------------------- 26.2/26.2 MB 24.1 MB/s  0:00:01
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading xxhash-3.6.0-cp39-cp39-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, sniffio, pyarrow, propcache, multidict, h11, frozenlist, dill, attrs, async-timeout, aiohappyeyeballs, yarl, multiprocess, httpcore, anyio, aiosignal, httpx, aiohttp, datasets
#
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    ---- -----------------------------------  2/19 [pyarrow]
#    -------------- -------------------------  7/19 [dill]
#    -------------- -------------------------  7/19 [dill]
#    ---------------- -----------------------  8/19 [attrs]
#    ------------------------- -------------- 12/19 [multiprocess]
#    --------------------------- ------------ 13/19 [httpcore]
#    ----------------------------- ---------- 14/19 [anyio]
#    ----------------------------- ---------- 14/19 [anyio]
#    --------------------------------- ------ 16/19 [httpx]
#    ----------------------------------- ---- 17/19 [aiohttp]
#    ----------------------------------- ---- 17/19 [aiohttp]
#    ------------------------------------- -- 18/19 [datasets]
#    ------------------------------------- -- 18/19 [datasets]
#    ------------------------------------- -- 18/19 [datasets]
#    ------------------------------------- -- 18/19 [datasets]
#    ---------------------------------------- 19/19 [datasets]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.0 aiosignal-1.4.0 anyio-4.11.0 async-timeout-5.0.1 attrs-25.4.0 datasets-4.2.0 dill-0.4.0 frozenlist-1.8.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 multidict-6.7.0 multiprocess-0.70.16 propcache-0.4.1 pyarrow-21.0.0 sniffio-1.3.1 xxhash-3.6.0 yarl-1.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (4.57.0)
# Requirement already satisfied: filelock in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests->transformers) (2025.10.5)

# %%
# %pip install tf_keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting tf_keras
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tf_keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.9)
# Requirement already satisfied: pillow in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (11.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf_keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tl1\anaconda3\envs\aiml_labexam\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.1.2)
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 30.5 MB/s  0:00:00
# Installing collected packages: tf_keras
# Successfully installed tf_keras-2.20.1
# Note: you may need to restart the kernel to use updated packages.
